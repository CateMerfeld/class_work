# %% [markdown]
# <a href="https://colab.research.google.com/github/CateMerfeld/class_work/blob/main/classifier_new_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization 
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model

from sklearn.metrics import classification_report, confusion_matrix

import matplotlib.pyplot as plt
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.utils import plot_model
import pathlib
import glob
import os
import tempfile

# %%
# define var for path to image data
train_dir = '/content/drive/MyDrive/Data_Science_Course/Capstones/Capstone_4/data/train/'
validation_dir = '/content/drive/MyDrive/Data_Science_Course/Capstones/Capstone_4/data/validation/'

# %%
img_height = 160 #@param {type:"number"}
img_width = 160 #@param {type:"number"}
batch_size = 32 #@param {type:"number"}

# %%
# create training dataset from images in train directory
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 3841 files belonging to 2 classes.

# %%
# create validation dataset from images in validation directory
validation_ds = tf.keras.preprocessing.image_dataset_from_directory(
    validation_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 1083 files belonging to 2 classes.

# %% [markdown]
# The documentation for `tf.data.Dataset` objects does not discuss an attribute for class distribution. Taking the length of each class's list of images is a work around to see distribution of classes.

# %%
# generate lists of edible and poisonous mushroom images and print out length of each
images = pathlib.Path(train_dir)
edible_mushrooms = list(images.glob('edible/*'))
poisonous_mushrooms = list(images.glob('poisonous/*'))
print(len(edible_mushrooms), 'edible mushroom images')
print(len(poisonous_mushrooms), 'poisonous mushroom images')
# Out:
# 3078 edible mushroom images
# 763 poisonous mushroom images

# %%
# save these numbers for use in determining initial bias
neg = len(edible_mushrooms)
pos = len(poisonous_mushrooms)

# %% [markdown]
# The dataset has over four times as many edible mushroom images as poisonous ones. This may affect model performance and need to be accounted for later.

# %%
# set input shape based on the channels' order
if K.image_data_format() == 'channels_first':
  input_shape = (3, img_width, img_height)
else:
  input_shape = (img_width, img_height, 3)

# %% [markdown]
# Looking at the first few images from the dataset, we can see that the images are taken from different angles and distances. Data augmentation will allow us to account for some of this by artificially altering the images.

# %%
# set augmentation configuration for training images
data_augmentation = keras.Sequential([
    layers.experimental.preprocessing.Rescaling(1./255, input_shape=input_shape),
    layers.experimental.preprocessing.RandomFlip('horizontal'),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.1)
])

# %% [markdown]
# This samle augmented image shows how data augmentation can be used to generate many variations of an image. This is especially useful since our dataset is not very large.

# %%
# visualize data augmentation on one image
for image, _ in train_ds.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0])
    plt.axis('off')

# %%
# use buffered prefetching so I/O doesn't become blocking
AUTOTUNE = tf.data.AUTOTUNE

# dataset.cache() keeps images in memory after they're loaded off disk during the first epoch
# dataset.prefetch() overlaps data preprocessing and model execution while training
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
validation_ds = validation_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Using the Keras Functional API, we can link the `data_augmentation` layer with traditional CNN layers like `MaxPooling2D`.

# %%
epochs =  50#@param {type: "number"}
batch_size =  128#@param {type:"number"}
learning_rate =  .001#@param {type:"number"}

# %% [markdown]
# Since the dataset is imbalanced, accuracy alone will not show how well the model is perfmorming. It could achieve 80% accuracy by classifying everything as edible. I'll use precision, recall and AUC as metrics in addition to accuracy.

# %%
# define metrics to be returned each epoch
METRICS = [
           keras.metrics.Precision(),
           keras.metrics.Recall(),
           keras.metrics.AUC(),
           keras.metrics.BinaryAccuracy()
]


def make_model(metrics=METRICS, output_bias=None):
  '''
  Sets up and compiles model using metrics and elements created above

  Arguments:
    metrics: evaluation metrics
    output_bias: optional, initial bias
  '''
  if output_bias is not None:
    output_bias = keras.initializers.Constant(output_bias)

  # set up model pipeline with elements created above
  inputs = keras.Input(shape=(input_shape))
  x = data_augmentation(inputs)
  x = Conv2D(8, kernel_size=4, activation='relu')(x)
  x = MaxPooling2D(pool_size=(2,2))(x)
  x = Flatten()(x)
  x = Dense(10, activation='relu')(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  outputs = Dense(1, activation='sigmoid', bias_initializer=output_bias)(x)
  model = keras.Model(inputs, outputs)

  opt = keras.optimizers.Adam(lr=learning_rate)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=metrics)

  return model

# %% [markdown]
# Since the dataset is imbalanced, it is reasonable to expect that this model won't perform very well. With default bias initialization we should be seeing loss of about `math.log(2) = .693`. This model is currently showing a loss of more than twice that.

# %%
model = make_model()
results = model.evaluate(train_ds, batch_size=batch_size, verbose=0)
results[0]
# Out:
# 1.384013056755066

# %% [markdown]
# To correct for this, I'll start by changing the bias of the model. According to a TensorFlow tutorial on classification on imbalanced data, the optimal starting bias can be determined by finding the log of positive/negative samples.

# %%
initial_bias = np.log([pos/neg])
initial_bias[0]
# Out:
# -1.3947772831143677

# %% [markdown]
# This loss is better than what we saw with naive initialization, but still higher than we should be seeing with this initialization.

# %%
model = make_model(output_bias = initial_bias)
results = model.evaluate(train_ds, batch_size=batch_size, verbose=0)
results[0]
# Out:
# 0.5236606001853943

# %%
# save model weights in a temporary file
initial_weights = os.path.join(tempfile.mkdtemp(), 'inital_weights')
model.save_weights(initial_weights)

# %%
# set up early stopping
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_auc', # use validation auc as monitor
    verbose=1, 
    patience=10, # wait 10 epochs before early stop
    mode='max', # training will stop when val_auc stops increasing
    restore_best_weights=True # restore weights from epoch where model performed best
)

# %%
model = make_model()
model.load_weights(initial_weights) # use the weights saved above in the new model

# train model and store as history object
baseline_history = model.fit(
    train_ds,
    epochs=epochs,
    callbacks=[early_stopping],
    validation_data=validation_ds,
)
# Out:
# Epoch 1/50
# 121/121 [==============================] - 3s 15ms/step - loss: 0.8658 - precision: 0.2480 - recall: 0.0175 - auc: 0.4977 - binary_accuracy: 0.7980 - val_loss: 0.4893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 2/50
# 121/121 [==============================] - 2s 13ms/step - loss: 0.5003 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - binary_accuracy: 0.8001 - val_loss: 0.4893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 3/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.5007 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - binary_accuracy: 0.8001 - val_loss: 0.4893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 4/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.5003 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - binary_accuracy: 0.8001 - val_loss: 0.4893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 5/50
# 121/121 [==============================] - 2s 12ms/step - loss: 0.5003 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - binary_accuracy: 0.8001 - val_loss: 0.4893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 6/50
# 121/121 [==============================] - 2s 12ms/step - loss: 0.5003 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - binary_accuracy: 0.8001 - val_loss: 0.4893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 7/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.5003 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - binary_accuracy: 0.8001 - val_loss: 0.4893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 8/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.5003 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - binary_accuracy: 0.8001 - val_loss: 0.4893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 9/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.5003 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - binary_accuracy: 0.8001 - val_loss: 0.4893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 10/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.5003 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - binary_accuracy: 0.8001 - val_loss: 0.4893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 11/50
# 121/121 [==============================] - 2s 12ms/step - loss: 0.5003 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - binary_accuracy: 0.8001 - val_loss: 0.4893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping

# %%
def plot_metrics(history):
  metrics = ['loss', ]

# %%
# get training and validation accuracy from the history object
tr_acc = baseline_history.history['binary_accuracy']
val_acc = baseline_history.history['val_binary_accuracy']

# get training and validation loss from the history object
tr_loss = baseline_history.history['loss']
val_loss = baseline_history.history['val_loss']

# plot accuracy and loss over epochs
epochs_range = range(epochs)

plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.plot(epochs_range, tr_acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2,1,2)
plt.plot(epochs_range, tr_loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper left')
plt.xlabel('Epoch')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')

plt.show()

# %%
true_labels = tf.concat([y for x, y in validation_ds], axis=0)
predictions = model.predict(validation_ds)
preds = np.argmax(predictions, axis=1)

# %%
predictions = model.predict(validation_ds)
preds = np.argmax(predictions, axis=1)

# %%
print('Confusion matrix:\n\n',confusion_matrix(preds, true_labels))
print('\n------------------------------------------------\n')
print('Classification report:\n\n',classification_report(true_labels, preds))
# Out:
# Confusion matrix:
#
#  [[875 208]
#  [  0   0]]
#
# ------------------------------------------------
#
# Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89       875
#            1       0.00      0.00      0.00       208
#
#     accuracy                           0.81      1083
#    macro avg       0.40      0.50      0.45      1083
# weighted avg       0.65      0.81      0.72      1083
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Although this model's accuracy scores are above 80% we can see from the precision and recall that it does not perform well at all. Currently the model is classifying everything as negative(edible).
#
# I'll try changing the class weights to make the model weigh examples from the underrepresented class, poisonous, more heavily than edible examples.

# %%
# scale by total/2 in order to keep loss at a similar level
total = neg+pos
weight_0 = (1/neg)*total/2.0
weight_1 = (1/pos)*total/2.0

# set up dictionary to hold weights
class_weights = {0: weight_0, 1: weight_1}

print('Class 0 weight: ', weight_0)
print('Class 1 weight: ', weight_1)
# Out:
# Class 0 weight:  0.6239441195581547
# Class 1 weight:  2.517038007863696

# %%
weighted_model = make_model()
weighted_model.load_weights(initial_weights)

weighted_history = weighted_model.fit(
    train_ds,
    epochs=epochs,
    callbacks=[early_stopping],
    validation_data=validation_ds,
    class_weight=class_weights
)
# Out:
# Epoch 1/50
# 121/121 [==============================] - 3s 15ms/step - loss: 1.4022 - precision: 0.1933 - recall: 0.0581 - auc: 0.4965 - binary_accuracy: 0.7693 - val_loss: 0.4907 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 2/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.8889 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4959 - binary_accuracy: 0.8001 - val_loss: 0.4939 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 3/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.8606 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5079 - binary_accuracy: 0.8001 - val_loss: 0.4987 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 4/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.8352 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4905 - binary_accuracy: 0.8001 - val_loss: 0.5051 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 5/50
# 121/121 [==============================] - 2s 14ms/step - loss: 0.8146 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5028 - binary_accuracy: 0.8001 - val_loss: 0.5130 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 6/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.7928 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5058 - binary_accuracy: 0.8001 - val_loss: 0.5219 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 7/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.7756 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4888 - binary_accuracy: 0.8001 - val_loss: 0.5318 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 8/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.7608 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5063 - binary_accuracy: 0.8001 - val_loss: 0.5424 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 9/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.7481 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5007 - binary_accuracy: 0.8001 - val_loss: 0.5535 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 10/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.7375 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4909 - binary_accuracy: 0.8001 - val_loss: 0.5649 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Epoch 11/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.7286 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4872 - binary_accuracy: 0.8001 - val_loss: 0.5764 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_binary_accuracy: 0.8079
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping

# %%
true_labels = tf.concat([y for x, y in validation_ds], axis=0)
predictions = weighted_model.predict(validation_ds)
preds = np.argmax(predictions, axis=1)

# %%
predictions = weighted_model.predict(validation_ds)
preds = np.argmax(predictions, axis=1)

# %%
print('Confusion matrix:\n\n',confusion_matrix(preds, true_labels))
print('\n------------------------------------------------\n')
print('Classification report:\n\n',classification_report(true_labels, preds))
# Out:
# Confusion matrix:
#
#  [[875 208]
#  [  0   0]]
#
# ------------------------------------------------
#
# Classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89       875
#            1       0.00      0.00      0.00       208
#
#     accuracy                           0.81      1083
#    macro avg       0.40      0.50      0.45      1083
# weighted avg       0.65      0.81      0.72      1083
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
epochs =  50#@param {type: "number"}
batch_size =  64#@param {type:"number"}
learning_rate =  .0001#@param {type:"number"}

# %% [markdown]
# Since the dataset is imbalanced, accuracy alone will not show how well the model is perfmorming. It could achieve 80% accuracy by classifying everything as edible. I'll use precision, recall and AUC as metrics in addition to accuracy.

# %%
# define metrics to be returned each epoch
METRICS = [
           keras.metrics.Precision(),
           keras.metrics.Recall(),
           keras.metrics.AUC(),
           keras.metrics.BinaryAccuracy()
]
# compile model
opt = keras.optimizers.Adam(lr=learning_rate)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=METRICS)

# %%
# train model and store as history object
history = model.fit(
    train_ds,
    epochs=epochs,
    validation_data=validation_ds,
)
# Out:
# Epoch 1/50
# 121/121 [==============================] - 4s 21ms/step - loss: 0.7417 - precision_2: 0.2082 - recall_2: 0.5457 - auc_2: 0.5252 - binary_accuracy: 0.5150 - val_loss: 0.7134 - val_precision_2: 0.2138 - val_recall_2: 0.9087 - val_auc_2: 0.5569 - val_binary_accuracy: 0.3407
# Epoch 2/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.6951 - precision_2: 0.1966 - recall_2: 0.4657 - auc_2: 0.5186 - binary_accuracy: 0.5320 - val_loss: 0.6224 - val_precision_2: 0.3158 - val_recall_2: 0.0288 - val_auc_2: 0.6408 - val_binary_accuracy: 0.8015
# Epoch 3/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.6495 - precision_2: 0.2049 - recall_2: 0.3613 - auc_2: 0.5563 - binary_accuracy: 0.6058 - val_loss: 0.6002 - val_precision_2: 0.3333 - val_recall_2: 0.0048 - val_auc_2: 0.6578 - val_binary_accuracy: 0.8070
# Epoch 4/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.6110 - precision_2: 0.2281 - recall_2: 0.0837 - auc_2: 0.5824 - binary_accuracy: 0.7633 - val_loss: 0.6135 - val_precision_2: 0.2927 - val_recall_2: 0.0577 - val_auc_2: 0.6488 - val_binary_accuracy: 0.7922
# Epoch 5/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.5812 - precision_2: 0.3642 - recall_2: 0.1823 - auc_2: 0.6174 - binary_accuracy: 0.7818 - val_loss: 0.6283 - val_precision_2: 0.2857 - val_recall_2: 0.4423 - val_auc_2: 0.6579 - val_binary_accuracy: 0.6805
# Epoch 6/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.5616 - precision_2: 0.3608 - recall_2: 0.1530 - auc_2: 0.6115 - binary_accuracy: 0.7865 - val_loss: 0.5070 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.6465 - val_binary_accuracy: 0.8079
# Epoch 7/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.5456 - precision_2: 0.6372 - recall_2: 0.0180 - auc_2: 0.6133 - binary_accuracy: 0.8073 - val_loss: 0.6186 - val_precision_2: 0.3233 - val_recall_2: 0.3606 - val_auc_2: 0.6660 - val_binary_accuracy: 0.7322
# Epoch 8/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.5272 - precision_2: 0.4599 - recall_2: 0.1040 - auc_2: 0.6026 - binary_accuracy: 0.8040 - val_loss: 0.4871 - val_precision_2: 0.3333 - val_recall_2: 0.0048 - val_auc_2: 0.6592 - val_binary_accuracy: 0.8070
# Epoch 9/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.5089 - precision_2: 0.3716 - recall_2: 0.0358 - auc_2: 0.6477 - binary_accuracy: 0.8040 - val_loss: 0.4750 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.6441 - val_binary_accuracy: 0.8079
# Epoch 10/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4993 - precision_2: 0.5427 - recall_2: 0.0397 - auc_2: 0.6350 - binary_accuracy: 0.8086 - val_loss: 0.4805 - val_precision_2: 0.6667 - val_recall_2: 0.0096 - val_auc_2: 0.6555 - val_binary_accuracy: 0.8089
# Epoch 11/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4857 - precision_2: 0.6488 - recall_2: 0.0450 - auc_2: 0.6491 - binary_accuracy: 0.8118 - val_loss: 0.4695 - val_precision_2: 0.6667 - val_recall_2: 0.0288 - val_auc_2: 0.6674 - val_binary_accuracy: 0.8107
# Epoch 12/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4758 - precision_2: 0.5660 - recall_2: 0.0451 - auc_2: 0.6690 - binary_accuracy: 0.8103 - val_loss: 0.4660 - val_precision_2: 0.5909 - val_recall_2: 0.0625 - val_auc_2: 0.6569 - val_binary_accuracy: 0.8116
# Epoch 13/50
# 121/121 [==============================] - 2s 17ms/step - loss: 0.4707 - precision_2: 0.4646 - recall_2: 0.0411 - auc_2: 0.6641 - binary_accuracy: 0.8072 - val_loss: 0.7095 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5301 - val_binary_accuracy: 0.8079
# Epoch 14/50
# 121/121 [==============================] - 2s 17ms/step - loss: 0.4756 - precision_2: 0.5552 - recall_2: 0.1134 - auc_2: 0.6343 - binary_accuracy: 0.8117 - val_loss: 0.4765 - val_precision_2: 0.4000 - val_recall_2: 0.0096 - val_auc_2: 0.6468 - val_binary_accuracy: 0.8070
# Epoch 15/50
# 121/121 [==============================] - 2s 17ms/step - loss: 0.4634 - precision_2: 0.4953 - recall_2: 0.0617 - auc_2: 0.6706 - binary_accuracy: 0.8079 - val_loss: 0.4953 - val_precision_2: 1.0000 - val_recall_2: 0.0096 - val_auc_2: 0.6511 - val_binary_accuracy: 0.8098
# Epoch 16/50
# 121/121 [==============================] - 2s 17ms/step - loss: 0.4635 - precision_2: 0.5676 - recall_2: 0.0745 - auc_2: 0.6637 - binary_accuracy: 0.8118 - val_loss: 0.4998 - val_precision_2: 1.0000 - val_recall_2: 0.0048 - val_auc_2: 0.6497 - val_binary_accuracy: 0.8089
# Epoch 17/50
# 121/121 [==============================] - 2s 17ms/step - loss: 0.4566 - precision_2: 0.6359 - recall_2: 0.0617 - auc_2: 0.6771 - binary_accuracy: 0.8127 - val_loss: 0.5009 - val_precision_2: 0.8889 - val_recall_2: 0.0385 - val_auc_2: 0.6503 - val_binary_accuracy: 0.8144
# Epoch 18/50
# 121/121 [==============================] - 2s 17ms/step - loss: 0.4611 - precision_2: 0.4422 - recall_2: 0.0750 - auc_2: 0.6674 - binary_accuracy: 0.8049 - val_loss: 0.4515 - val_precision_2: 0.8571 - val_recall_2: 0.0577 - val_auc_2: 0.6878 - val_binary_accuracy: 0.8172
# Epoch 19/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4530 - precision_2: 0.6217 - recall_2: 0.0552 - auc_2: 0.6774 - binary_accuracy: 0.8119 - val_loss: 0.4618 - val_precision_2: 0.6452 - val_recall_2: 0.0962 - val_auc_2: 0.6762 - val_binary_accuracy: 0.8163
# Epoch 20/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4528 - precision_2: 0.4402 - recall_2: 0.0619 - auc_2: 0.6823 - binary_accuracy: 0.8048 - val_loss: 0.4597 - val_precision_2: 0.6364 - val_recall_2: 0.1010 - val_auc_2: 0.6759 - val_binary_accuracy: 0.8163
# Epoch 21/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4493 - precision_2: 0.6203 - recall_2: 0.0759 - auc_2: 0.6771 - binary_accuracy: 0.8139 - val_loss: 0.4533 - val_precision_2: 0.5556 - val_recall_2: 0.0962 - val_auc_2: 0.6809 - val_binary_accuracy: 0.8116
# Epoch 22/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4434 - precision_2: 0.6244 - recall_2: 0.0867 - auc_2: 0.7003 - binary_accuracy: 0.8150 - val_loss: 0.4642 - val_precision_2: 0.7333 - val_recall_2: 0.0529 - val_auc_2: 0.6721 - val_binary_accuracy: 0.8144
# Epoch 23/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4404 - precision_2: 0.6624 - recall_2: 0.0991 - auc_2: 0.7025 - binary_accuracy: 0.8172 - val_loss: 0.4586 - val_precision_2: 0.6061 - val_recall_2: 0.0962 - val_auc_2: 0.6789 - val_binary_accuracy: 0.8144
# Epoch 24/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4489 - precision_2: 0.6031 - recall_2: 0.0927 - auc_2: 0.6914 - binary_accuracy: 0.8144 - val_loss: 0.4627 - val_precision_2: 0.5652 - val_recall_2: 0.0625 - val_auc_2: 0.6776 - val_binary_accuracy: 0.8107
# Epoch 25/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4422 - precision_2: 0.6608 - recall_2: 0.1038 - auc_2: 0.6994 - binary_accuracy: 0.8181 - val_loss: 0.4572 - val_precision_2: 0.6129 - val_recall_2: 0.0913 - val_auc_2: 0.6793 - val_binary_accuracy: 0.8144
# Epoch 26/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4423 - precision_2: 0.5515 - recall_2: 0.0904 - auc_2: 0.7052 - binary_accuracy: 0.8112 - val_loss: 0.4645 - val_precision_2: 0.6087 - val_recall_2: 0.0673 - val_auc_2: 0.6714 - val_binary_accuracy: 0.8126
# Epoch 27/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4382 - precision_2: 0.6507 - recall_2: 0.1035 - auc_2: 0.7093 - binary_accuracy: 0.8173 - val_loss: 0.4463 - val_precision_2: 0.6667 - val_recall_2: 0.0962 - val_auc_2: 0.6998 - val_binary_accuracy: 0.8172
# Epoch 28/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4336 - precision_2: 0.6993 - recall_2: 0.1229 - auc_2: 0.7200 - binary_accuracy: 0.8216 - val_loss: 0.4484 - val_precision_2: 0.6500 - val_recall_2: 0.0625 - val_auc_2: 0.6991 - val_binary_accuracy: 0.8135
# Epoch 29/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4367 - precision_2: 0.6476 - recall_2: 0.0983 - auc_2: 0.7185 - binary_accuracy: 0.8169 - val_loss: 0.4526 - val_precision_2: 0.6538 - val_recall_2: 0.0817 - val_auc_2: 0.6949 - val_binary_accuracy: 0.8153
# Epoch 30/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4372 - precision_2: 0.6430 - recall_2: 0.1156 - auc_2: 0.7124 - binary_accuracy: 0.8177 - val_loss: 0.4433 - val_precision_2: 0.6585 - val_recall_2: 0.1298 - val_auc_2: 0.6986 - val_binary_accuracy: 0.8199
# Epoch 31/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4306 - precision_2: 0.7343 - recall_2: 0.1295 - auc_2: 0.7205 - binary_accuracy: 0.8237 - val_loss: 0.4569 - val_precision_2: 0.6190 - val_recall_2: 0.0625 - val_auc_2: 0.6846 - val_binary_accuracy: 0.8126
# Epoch 32/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4347 - precision_2: 0.6534 - recall_2: 0.1000 - auc_2: 0.7228 - binary_accuracy: 0.8173 - val_loss: 0.4434 - val_precision_2: 0.6122 - val_recall_2: 0.1442 - val_auc_2: 0.7048 - val_binary_accuracy: 0.8181
# Epoch 33/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4341 - precision_2: 0.6848 - recall_2: 0.1357 - auc_2: 0.7258 - binary_accuracy: 0.8220 - val_loss: 0.4547 - val_precision_2: 0.6032 - val_recall_2: 0.1827 - val_auc_2: 0.6909 - val_binary_accuracy: 0.8199
# Epoch 34/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4305 - precision_2: 0.6184 - recall_2: 0.1322 - auc_2: 0.7265 - binary_accuracy: 0.8175 - val_loss: 0.4520 - val_precision_2: 0.6140 - val_recall_2: 0.1683 - val_auc_2: 0.7127 - val_binary_accuracy: 0.8199
# Epoch 35/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4367 - precision_2: 0.5993 - recall_2: 0.1422 - auc_2: 0.7094 - binary_accuracy: 0.8171 - val_loss: 0.4532 - val_precision_2: 0.6136 - val_recall_2: 0.1298 - val_auc_2: 0.6964 - val_binary_accuracy: 0.8172
# Epoch 36/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4271 - precision_2: 0.6965 - recall_2: 0.1325 - auc_2: 0.7352 - binary_accuracy: 0.8224 - val_loss: 0.4550 - val_precision_2: 0.6296 - val_recall_2: 0.0817 - val_auc_2: 0.6978 - val_binary_accuracy: 0.8144
# Epoch 37/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4284 - precision_2: 0.6890 - recall_2: 0.1427 - auc_2: 0.7361 - binary_accuracy: 0.8233 - val_loss: 0.4513 - val_precision_2: 0.6129 - val_recall_2: 0.0913 - val_auc_2: 0.6946 - val_binary_accuracy: 0.8144
# Epoch 38/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4295 - precision_2: 0.6484 - recall_2: 0.1481 - auc_2: 0.7245 - binary_accuracy: 0.8209 - val_loss: 0.4541 - val_precision_2: 0.6098 - val_recall_2: 0.1202 - val_auc_2: 0.6973 - val_binary_accuracy: 0.8163
# Epoch 39/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4248 - precision_2: 0.7345 - recall_2: 0.1453 - auc_2: 0.7363 - binary_accuracy: 0.8259 - val_loss: 0.4583 - val_precision_2: 0.6364 - val_recall_2: 0.1346 - val_auc_2: 0.6973 - val_binary_accuracy: 0.8190
# Epoch 40/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4219 - precision_2: 0.7318 - recall_2: 0.1774 - auc_2: 0.7309 - binary_accuracy: 0.8297 - val_loss: 0.4681 - val_precision_2: 0.5806 - val_recall_2: 0.0865 - val_auc_2: 0.6910 - val_binary_accuracy: 0.8126
# Epoch 41/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4231 - precision_2: 0.6754 - recall_2: 0.1460 - auc_2: 0.7431 - binary_accuracy: 0.8229 - val_loss: 0.4608 - val_precision_2: 0.5833 - val_recall_2: 0.0673 - val_auc_2: 0.6922 - val_binary_accuracy: 0.8116
# Epoch 42/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4208 - precision_2: 0.6892 - recall_2: 0.1670 - auc_2: 0.7568 - binary_accuracy: 0.8264 - val_loss: 0.4640 - val_precision_2: 0.6562 - val_recall_2: 0.1010 - val_auc_2: 0.6945 - val_binary_accuracy: 0.8172
# Epoch 43/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4222 - precision_2: 0.6639 - recall_2: 0.1640 - auc_2: 0.7448 - binary_accuracy: 0.8236 - val_loss: 0.4662 - val_precision_2: 0.7097 - val_recall_2: 0.1058 - val_auc_2: 0.6907 - val_binary_accuracy: 0.8199
# Epoch 44/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4214 - precision_2: 0.6743 - recall_2: 0.1494 - auc_2: 0.7409 - binary_accuracy: 0.8233 - val_loss: 0.4600 - val_precision_2: 0.6579 - val_recall_2: 0.1202 - val_auc_2: 0.6958 - val_binary_accuracy: 0.8190
# Epoch 45/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4210 - precision_2: 0.7161 - recall_2: 0.1399 - auc_2: 0.7430 - binary_accuracy: 0.8243 - val_loss: 0.4541 - val_precision_2: 0.6471 - val_recall_2: 0.1058 - val_auc_2: 0.7009 - val_binary_accuracy: 0.8172
# Epoch 46/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4177 - precision_2: 0.6825 - recall_2: 0.1587 - auc_2: 0.7517 - binary_accuracy: 0.8250 - val_loss: 0.4499 - val_precision_2: 0.6667 - val_recall_2: 0.0962 - val_auc_2: 0.7017 - val_binary_accuracy: 0.8172
# Epoch 47/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4108 - precision_2: 0.7164 - recall_2: 0.1717 - auc_2: 0.7633 - binary_accuracy: 0.8287 - val_loss: 0.4503 - val_precision_2: 0.6250 - val_recall_2: 0.1202 - val_auc_2: 0.6955 - val_binary_accuracy: 0.8172
# Epoch 48/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4183 - precision_2: 0.6525 - recall_2: 0.1408 - auc_2: 0.7600 - binary_accuracy: 0.8210 - val_loss: 0.4553 - val_precision_2: 0.6286 - val_recall_2: 0.1058 - val_auc_2: 0.6968 - val_binary_accuracy: 0.8163
# Epoch 49/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4119 - precision_2: 0.7032 - recall_2: 0.1599 - auc_2: 0.7647 - binary_accuracy: 0.8258 - val_loss: 0.4582 - val_precision_2: 0.6571 - val_recall_2: 0.1106 - val_auc_2: 0.6995 - val_binary_accuracy: 0.8181
# Epoch 50/50
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4140 - precision_2: 0.7011 - recall_2: 0.1846 - auc_2: 0.7563 - binary_accuracy: 0.8283 - val_loss: 0.4629 - val_precision_2: 0.6667 - val_recall_2: 0.1058 - val_auc_2: 0.6961 - val_binary_accuracy: 0.8181

# %%
# The base model, MobileNetV2, expects pixel values in [-1,1]. 
# This preprocessing is included with the model and will rescale the pixel values
preprocess_input = keras.applications.mobilenet_v2.preprocess_input

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=input_shape,
                                               include_top=False,
                                               weights='imagenet')

# %%
# freeze convolutional base so that weights will not be updated during training
base_model.trainable = False

# %%
image_batch, label_batch = next(iter(train_ds))
feature_batch = base_model(image_batch)
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 1280)

# %%
prediction_layer = keras.layers.Dense(1)
prediction_batch = prediction_layer(feature_batch_average)
prediction_batch.shape
# Out:
# TensorShape([32, 1])

# %%
inputs = keras.Input(shape=(input_shape))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = global_average_layer(x)
x = Dropout(0.2)(x)
outputs = prediction_layer(x)
model = Model(inputs, outputs)

# %%
#@markdown ### Set learning rate and number of epochs:
learning_rate =  .0001#@param {type:"number"}
epochs = 10 #@param {type: "number"}

# %%
opt = keras.optimizers.Adam(lr=learning_rate)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# %%
loss, accuracy = model.evaluate(validation_ds)
# Out:
# 34/34 [==============================] - 2s 26ms/step - loss: 3.0160 - accuracy: 0.8045

# %%
# train model and store as history object
history = model.fit(
    train_ds,
    epochs=epochs,
    validation_data=validation_ds,
)
# Out:
# Epoch 1/10
# 121/121 [==============================] - 7s 34ms/step - loss: 2.3306 - accuracy: 0.7402 - val_loss: 0.5182 - val_accuracy: 0.8079
# Epoch 2/10
# 121/121 [==============================] - 4s 33ms/step - loss: 2.0571 - accuracy: 0.7126 - val_loss: 0.5199 - val_accuracy: 0.8079
# Epoch 3/10
# 121/121 [==============================] - 4s 33ms/step - loss: 1.9752 - accuracy: 0.7040 - val_loss: 2.4473 - val_accuracy: 0.8079
# Epoch 4/10
# 121/121 [==============================] - 4s 33ms/step - loss: 2.0142 - accuracy: 0.7248 - val_loss: 2.9524 - val_accuracy: 0.8079
# Epoch 5/10
# 121/121 [==============================] - 4s 33ms/step - loss: 2.0524 - accuracy: 0.7232 - val_loss: 1.0730 - val_accuracy: 0.8079
# Epoch 6/10
# 121/121 [==============================] - 4s 33ms/step - loss: 2.2463 - accuracy: 0.6100 - val_loss: 0.4905 - val_accuracy: 0.8079
# Epoch 7/10
# 121/121 [==============================] - 4s 33ms/step - loss: 2.0697 - accuracy: 0.6540 - val_loss: 0.5050 - val_accuracy: 0.8079
# Epoch 8/10
# 121/121 [==============================] - 4s 33ms/step - loss: 2.0881 - accuracy: 0.7001 - val_loss: 2.9515 - val_accuracy: 0.8079
# Epoch 9/10
# 121/121 [==============================] - 4s 33ms/step - loss: 2.2948 - accuracy: 0.7456 - val_loss: 2.6198 - val_accuracy: 0.8079
# Epoch 10/10
# 121/121 [==============================] - 4s 33ms/step - loss: 2.0710 - accuracy: 0.7019 - val_loss: 0.5058 - val_accuracy: 0.8079

# %%
# retrieve class names from dataset
class_names = train_ds.class_names

# plot first 9 images from training dataset
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3,3,i+1)
    plt.imshow(images[i].numpy().astype('uint8'))
    plt.title(class_names[labels[i]])
    plt.axis('off')
