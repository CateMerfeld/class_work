# %% [markdown]
# <a href="https://colab.research.google.com/github/CateMerfeld/class_work/blob/main/deep_learning_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from tensorflow.keras.datasets import fashion_mnist
# !pip install tensorflow-gpu==2.0.0-rc1
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, LeakyReLU
# import warnings
# warnings.filterwarnings('ignore')

# from tensorflow.keras.utils import to_categorical
# import matplotlib.pyplot as plt
# import pandas as pd
# from keras.layers import  Conv2D, MaxPooling2D

# %% [markdown]
# # Preprocess your data so that you can feed it into ANN models. Split your data into training and test sets:
# ---
# This dataset is already separated into training and testing when we load it. See preprocessing below.

# %%
# load data and preprocess
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
# 28*28 = dimensions of each image
input_dim = 784 
# dataset documentation specifies that there are 10 classes
output_dim = nb_classes = 10

# reshape images so they can be fed into model
X_train = X_train.reshape(60000, input_dim)
X_test = X_test.reshape(10000, input_dim)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# %% [markdown]
# # Try different ANN models and train them on your training set:
# ---
# You can play with the following:
#
# * Number of layers
# * Activation functions of the layers
# * Number of neurons in the layers
# * Different batch sizes during training
#
# **Compare your models' training scores and interpret your results.**
#
# **Evaluate how your models perform on your test set. Compare the results of your models.**

# %%
# one-hot encode target variable using to_categorical()
y_train = to_categorical(y_train, nb_classes)
y_test = to_categorical(y_test, nb_classes)

# %% [markdown]
# Starting with a very simple model.

# %%
# create a model object
model = Sequential()

# add layers to the model
# first dense layer
model.add(Dense(64, input_shape=(784,), activation='tanh'))
# second dense layer
model.add(Dense(64, activation='tanh'))
# output layer
model.add(Dense(10, activation='softmax'))

# %%
# define an optimizer and compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

batch_size = 80
epochs = 20

# fit model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 4s 3ms/step - loss: 0.7037 - accuracy: 0.7580 - val_loss: 0.4311 - val_accuracy: 0.8439
# Epoch 2/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3860 - accuracy: 0.8602 - val_loss: 0.4007 - val_accuracy: 0.8540
# Epoch 3/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3445 - accuracy: 0.8735 - val_loss: 0.3685 - val_accuracy: 0.8660
# Epoch 4/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3222 - accuracy: 0.8796 - val_loss: 0.3794 - val_accuracy: 0.8612
# Epoch 5/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3078 - accuracy: 0.8884 - val_loss: 0.3653 - val_accuracy: 0.8688
# Epoch 6/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2932 - accuracy: 0.8923 - val_loss: 0.3575 - val_accuracy: 0.8697
# Epoch 7/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2777 - accuracy: 0.8983 - val_loss: 0.3416 - val_accuracy: 0.8751
# Epoch 8/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2612 - accuracy: 0.9023 - val_loss: 0.3348 - val_accuracy: 0.8782
# Epoch 9/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2569 - accuracy: 0.9023 - val_loss: 0.3331 - val_accuracy: 0.8800
# Epoch 10/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2409 - accuracy: 0.9106 - val_loss: 0.3415 - val_accuracy: 0.8756
# Epoch 11/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2463 - accuracy: 0.9074 - val_loss: 0.3293 - val_accuracy: 0.8801
# Epoch 12/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2306 - accuracy: 0.9156 - val_loss: 0.3294 - val_accuracy: 0.8826
# Epoch 13/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2263 - accuracy: 0.9162 - val_loss: 0.3222 - val_accuracy: 0.8833
# Epoch 14/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2207 - accuracy: 0.9180 - val_loss: 0.3351 - val_accuracy: 0.8809
# Epoch 15/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2184 - accuracy: 0.9172 - val_loss: 0.3480 - val_accuracy: 0.8792
# Epoch 16/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2112 - accuracy: 0.9211 - val_loss: 0.3271 - val_accuracy: 0.8835
# Epoch 17/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2039 - accuracy: 0.9231 - val_loss: 0.3366 - val_accuracy: 0.8841
# Epoch 18/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1988 - accuracy: 0.9260 - val_loss: 0.3396 - val_accuracy: 0.8810
# Epoch 19/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1970 - accuracy: 0.9270 - val_loss: 0.3432 - val_accuracy: 0.8812
# Epoch 20/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1869 - accuracy: 0.9299 - val_loss: 0.3379 - val_accuracy: 0.8823

# %%
df = pd.DataFrame(history.history)
df[['accuracy', 'val_accuracy']].plot(figsize=(20,10))
plt.show()

# %% [markdown]
# This model comes in at about 93% accuracy for the training set and about 88% for the testing set. We're not seeing enormous loss for either set.
#
# I'll try this same model with an additional layer.

# %%
# create a model object
model = Sequential()

# add layers to the model
# first dense layer
model.add(Dense(64, input_shape=(784,), activation='tanh'))
# second dense layer
model.add(Dense(64, activation='tanh'))
# third dense layer
model.add(Dense(32, activation='tanh'))
# output layer
model.add(Dense(10, activation='softmax'))

# define an optimizer and compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

batch_size = 80
epochs = 20

# fit model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.7520 - accuracy: 0.7511 - val_loss: 0.4437 - val_accuracy: 0.8375
# Epoch 2/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3855 - accuracy: 0.8623 - val_loss: 0.3898 - val_accuracy: 0.8599
# Epoch 3/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3415 - accuracy: 0.8751 - val_loss: 0.4156 - val_accuracy: 0.8505
# Epoch 4/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3248 - accuracy: 0.8822 - val_loss: 0.3623 - val_accuracy: 0.8689
# Epoch 5/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3012 - accuracy: 0.8898 - val_loss: 0.3645 - val_accuracy: 0.8693
# Epoch 6/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2859 - accuracy: 0.8952 - val_loss: 0.3502 - val_accuracy: 0.8728
# Epoch 7/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2754 - accuracy: 0.8991 - val_loss: 0.3645 - val_accuracy: 0.8702
# Epoch 8/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2653 - accuracy: 0.9023 - val_loss: 0.3492 - val_accuracy: 0.8756
# Epoch 9/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2544 - accuracy: 0.9048 - val_loss: 0.3408 - val_accuracy: 0.8749
# Epoch 10/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2449 - accuracy: 0.9078 - val_loss: 0.3464 - val_accuracy: 0.8742
# Epoch 11/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2391 - accuracy: 0.9115 - val_loss: 0.3338 - val_accuracy: 0.8807
# Epoch 12/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2299 - accuracy: 0.9138 - val_loss: 0.3364 - val_accuracy: 0.8792
# Epoch 13/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2235 - accuracy: 0.9169 - val_loss: 0.3318 - val_accuracy: 0.8817
# Epoch 14/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2187 - accuracy: 0.9195 - val_loss: 0.3291 - val_accuracy: 0.8815
# Epoch 15/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2084 - accuracy: 0.9221 - val_loss: 0.3399 - val_accuracy: 0.8826
# Epoch 16/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2079 - accuracy: 0.9217 - val_loss: 0.3258 - val_accuracy: 0.8827
# Epoch 17/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2000 - accuracy: 0.9250 - val_loss: 0.3316 - val_accuracy: 0.8816
# Epoch 18/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1942 - accuracy: 0.9278 - val_loss: 0.3561 - val_accuracy: 0.8789
# Epoch 19/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1891 - accuracy: 0.9288 - val_loss: 0.3680 - val_accuracy: 0.8710
# Epoch 20/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1868 - accuracy: 0.9311 - val_loss: 0.3506 - val_accuracy: 0.8781

# %%
df = pd.DataFrame(history.history)
df[['accuracy', 'val_accuracy']].plot(figsize=(20,10))
plt.show()

# %% [markdown]
# The scores for this model are very similar. We saw a very slight increase in accuracy for the training set, and a very slight accuracy decrease for the test set. The test set's loss also increased.
#
# Since this model's performance was slightly worse than the first model's, I'll try changing the first model to use `relu` activation.

# %%
# create a model object
model = Sequential()

# add layers to the model
# first dense layer
model.add(Dense(64, input_shape=(784,), activation='relu'))
# second dense layer
model.add(Dense(64, activation='relu'))
# output layer
model.add(Dense(10, activation='softmax'))

# define an optimizer and compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

batch_size = 80
epochs = 20

# fit model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.7664 - accuracy: 0.7361 - val_loss: 0.4452 - val_accuracy: 0.8436
# Epoch 2/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4149 - accuracy: 0.8532 - val_loss: 0.4180 - val_accuracy: 0.8510
# Epoch 3/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3580 - accuracy: 0.8693 - val_loss: 0.3976 - val_accuracy: 0.8569
# Epoch 4/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3322 - accuracy: 0.8789 - val_loss: 0.3717 - val_accuracy: 0.8663
# Epoch 5/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3119 - accuracy: 0.8873 - val_loss: 0.3676 - val_accuracy: 0.8721
# Epoch 6/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2943 - accuracy: 0.8913 - val_loss: 0.3553 - val_accuracy: 0.8744
# Epoch 7/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2929 - accuracy: 0.8920 - val_loss: 0.3628 - val_accuracy: 0.8715
# Epoch 8/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2762 - accuracy: 0.8966 - val_loss: 0.3490 - val_accuracy: 0.8770
# Epoch 9/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2665 - accuracy: 0.8997 - val_loss: 0.3361 - val_accuracy: 0.8817
# Epoch 10/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2580 - accuracy: 0.9033 - val_loss: 0.3362 - val_accuracy: 0.8806
# Epoch 11/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2514 - accuracy: 0.9058 - val_loss: 0.3429 - val_accuracy: 0.8774
# Epoch 12/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2447 - accuracy: 0.9095 - val_loss: 0.3387 - val_accuracy: 0.8801
# Epoch 13/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2408 - accuracy: 0.9107 - val_loss: 0.3346 - val_accuracy: 0.8792
# Epoch 14/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2309 - accuracy: 0.9128 - val_loss: 0.3436 - val_accuracy: 0.8815
# Epoch 15/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2306 - accuracy: 0.9134 - val_loss: 0.3444 - val_accuracy: 0.8815
# Epoch 16/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2187 - accuracy: 0.9173 - val_loss: 0.3338 - val_accuracy: 0.8827
# Epoch 17/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2161 - accuracy: 0.9194 - val_loss: 0.3371 - val_accuracy: 0.8852
# Epoch 18/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2087 - accuracy: 0.9226 - val_loss: 0.3418 - val_accuracy: 0.8837
# Epoch 19/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2028 - accuracy: 0.9241 - val_loss: 0.3446 - val_accuracy: 0.8808
# Epoch 20/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2028 - accuracy: 0.9246 - val_loss: 0.3467 - val_accuracy: 0.8812

# %%
df = pd.DataFrame(history.history)
df[['accuracy', 'val_accuracy']].plot(figsize=(20,10))
plt.show()

# %% [markdown]
# Although the differences were slight, this model's performance was worse than the first model's across the board. It performed slightly better than the last model on the test data.
#
# Next I'll try the first model again, with a different batch size.

# %%
# create a model object
model = Sequential()

# add layers to the model
# first dense layer
model.add(Dense(64, input_shape=(784,), activation='tanh'))
# second dense layer
model.add(Dense(64, activation='tanh'))
# output layer
model.add(Dense(10, activation='softmax'))

# define an optimizer and compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

batch_size = 120
epochs = 20

# fit model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/20
# 500/500 [==============================] - 2s 3ms/step - loss: 0.7643 - accuracy: 0.7461 - val_loss: 0.4393 - val_accuracy: 0.8411
# Epoch 2/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.3976 - accuracy: 0.8557 - val_loss: 0.4187 - val_accuracy: 0.8520
# Epoch 3/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.3571 - accuracy: 0.8706 - val_loss: 0.3860 - val_accuracy: 0.8599
# Epoch 4/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.3279 - accuracy: 0.8799 - val_loss: 0.3732 - val_accuracy: 0.8680
# Epoch 5/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.3144 - accuracy: 0.8835 - val_loss: 0.3606 - val_accuracy: 0.8680
# Epoch 6/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2975 - accuracy: 0.8911 - val_loss: 0.3492 - val_accuracy: 0.8740
# Epoch 7/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2793 - accuracy: 0.8997 - val_loss: 0.3496 - val_accuracy: 0.8764
# Epoch 8/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2720 - accuracy: 0.8986 - val_loss: 0.3404 - val_accuracy: 0.8762
# Epoch 9/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2653 - accuracy: 0.9024 - val_loss: 0.3319 - val_accuracy: 0.8830
# Epoch 10/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2493 - accuracy: 0.9091 - val_loss: 0.3410 - val_accuracy: 0.8799
# Epoch 11/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2419 - accuracy: 0.9093 - val_loss: 0.3421 - val_accuracy: 0.8811
# Epoch 12/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2388 - accuracy: 0.9120 - val_loss: 0.3223 - val_accuracy: 0.8842
# Epoch 13/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2282 - accuracy: 0.9174 - val_loss: 0.3248 - val_accuracy: 0.8854
# Epoch 14/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2248 - accuracy: 0.9166 - val_loss: 0.3299 - val_accuracy: 0.8835
# Epoch 15/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2175 - accuracy: 0.9190 - val_loss: 0.3297 - val_accuracy: 0.8844
# Epoch 16/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2130 - accuracy: 0.9201 - val_loss: 0.3264 - val_accuracy: 0.8849
# Epoch 17/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2112 - accuracy: 0.9209 - val_loss: 0.3357 - val_accuracy: 0.8815
# Epoch 18/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.2048 - accuracy: 0.9240 - val_loss: 0.3278 - val_accuracy: 0.8836
# Epoch 19/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.1936 - accuracy: 0.9268 - val_loss: 0.3302 - val_accuracy: 0.8886
# Epoch 20/20
# 500/500 [==============================] - 1s 3ms/step - loss: 0.1946 - accuracy: 0.9268 - val_loss: 0.3442 - val_accuracy: 0.8790

# %%
df = pd.DataFrame(history.history)
df[['accuracy', 'val_accuracy']].plot(figsize=(20,10))
plt.show()

# %% [markdown]
# This model's performance was also worse across the board. I'll try one more model where I change the number of neurons in the layers.

# %%
# create a model object
model = Sequential()

# add layers to the model
# first dense layer
model.add(Dense(256, input_shape=(784,), activation='tanh'))
# second dense layer
model.add(Dense(128, activation='tanh'))
# output layer
model.add(Dense(10, activation='softmax'))

# define an optimizer and compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

batch_size = 80
epochs = 20

# fit model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 3s 3ms/step - loss: 0.5860 - accuracy: 0.7904 - val_loss: 0.4078 - val_accuracy: 0.8536
# Epoch 2/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3702 - accuracy: 0.8652 - val_loss: 0.4228 - val_accuracy: 0.8436
# Epoch 3/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3319 - accuracy: 0.8762 - val_loss: 0.3569 - val_accuracy: 0.8688
# Epoch 4/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3034 - accuracy: 0.8872 - val_loss: 0.3478 - val_accuracy: 0.8734
# Epoch 5/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2797 - accuracy: 0.8958 - val_loss: 0.3463 - val_accuracy: 0.8737
# Epoch 6/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2672 - accuracy: 0.9006 - val_loss: 0.3310 - val_accuracy: 0.8787
# Epoch 7/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2510 - accuracy: 0.9073 - val_loss: 0.3263 - val_accuracy: 0.8808
# Epoch 8/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2415 - accuracy: 0.9099 - val_loss: 0.3492 - val_accuracy: 0.8719
# Epoch 9/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2314 - accuracy: 0.9135 - val_loss: 0.3245 - val_accuracy: 0.8845
# Epoch 10/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2200 - accuracy: 0.9155 - val_loss: 0.3208 - val_accuracy: 0.8847
# Epoch 11/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2112 - accuracy: 0.9208 - val_loss: 0.3311 - val_accuracy: 0.8818
# Epoch 12/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2034 - accuracy: 0.9229 - val_loss: 0.3244 - val_accuracy: 0.8863
# Epoch 13/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1969 - accuracy: 0.9271 - val_loss: 0.3154 - val_accuracy: 0.8900
# Epoch 14/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1914 - accuracy: 0.9280 - val_loss: 0.3221 - val_accuracy: 0.8864
# Epoch 15/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1875 - accuracy: 0.9302 - val_loss: 0.3234 - val_accuracy: 0.8885
# Epoch 16/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1846 - accuracy: 0.9307 - val_loss: 0.3067 - val_accuracy: 0.8939
# Epoch 17/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1746 - accuracy: 0.9346 - val_loss: 0.3275 - val_accuracy: 0.8830
# Epoch 18/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1631 - accuracy: 0.9405 - val_loss: 0.3418 - val_accuracy: 0.8842
# Epoch 19/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1606 - accuracy: 0.9409 - val_loss: 0.3285 - val_accuracy: 0.8882
# Epoch 20/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1559 - accuracy: 0.9411 - val_loss: 0.3254 - val_accuracy: 0.8912

# %%
df = pd.DataFrame(history.history)
df[['accuracy', 'val_accuracy']].plot(figsize=(20,10))
plt.show()

# %% [markdown]
# This model's performance was better than than the first model's. I'll try adjusting this number of neurons up again to see if I can get it to perform better.

# %%
# create a model object
model = Sequential()

# add layers to the model
# first dense layer
model.add(Dense(512, input_shape=(784,), activation='tanh'))
# second dense layer
model.add(Dense(256, activation='tanh'))
# output layer
model.add(Dense(10, activation='softmax'))

# define an optimizer and compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

batch_size = 80
epochs = 20

# fit model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5902 - accuracy: 0.7843 - val_loss: 0.4619 - val_accuracy: 0.8301
# Epoch 2/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3739 - accuracy: 0.8633 - val_loss: 0.3653 - val_accuracy: 0.8659
# Epoch 3/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3272 - accuracy: 0.8783 - val_loss: 0.3706 - val_accuracy: 0.8680
# Epoch 4/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3055 - accuracy: 0.8857 - val_loss: 0.3412 - val_accuracy: 0.8771
# Epoch 5/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2886 - accuracy: 0.8920 - val_loss: 0.3382 - val_accuracy: 0.8745
# Epoch 6/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2692 - accuracy: 0.8981 - val_loss: 0.3502 - val_accuracy: 0.8746
# Epoch 7/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2579 - accuracy: 0.9034 - val_loss: 0.3425 - val_accuracy: 0.8759
# Epoch 8/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2496 - accuracy: 0.9052 - val_loss: 0.3193 - val_accuracy: 0.8849
# Epoch 9/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2351 - accuracy: 0.9104 - val_loss: 0.3450 - val_accuracy: 0.8786
# Epoch 10/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2328 - accuracy: 0.9130 - val_loss: 0.3283 - val_accuracy: 0.8836
# Epoch 11/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2221 - accuracy: 0.9160 - val_loss: 0.3496 - val_accuracy: 0.8744
# Epoch 12/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2146 - accuracy: 0.9192 - val_loss: 0.3374 - val_accuracy: 0.8850
# Epoch 13/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2055 - accuracy: 0.9219 - val_loss: 0.3319 - val_accuracy: 0.8833
# Epoch 14/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2039 - accuracy: 0.9222 - val_loss: 0.3177 - val_accuracy: 0.8877
# Epoch 15/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1904 - accuracy: 0.9300 - val_loss: 0.3235 - val_accuracy: 0.8898
# Epoch 16/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1935 - accuracy: 0.9289 - val_loss: 0.3183 - val_accuracy: 0.8885
# Epoch 17/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1905 - accuracy: 0.9278 - val_loss: 0.3341 - val_accuracy: 0.8855
# Epoch 18/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1820 - accuracy: 0.9306 - val_loss: 0.3176 - val_accuracy: 0.8901
# Epoch 19/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1771 - accuracy: 0.9326 - val_loss: 0.3348 - val_accuracy: 0.8884
# Epoch 20/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1752 - accuracy: 0.9327 - val_loss: 0.3380 - val_accuracy: 0.8859

# %% [markdown]
# This model performed worse across the board vs. the last model. The last model performed better than any of the other models.
